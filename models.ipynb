# %%
import pandas as pd

# %%
df = pd.read_csv('to_analyze.csv')
df.head()
# Out:
#    valence  year  acousticness  danceability  duration_ms  energy  explicit  \
# 0    0.145  2020        0.4010         0.731       205090   0.573         1
# 1    0.756  2020        0.2210         0.700       140526   0.722         1
# 2    0.737  2020        0.0112         0.746       199054   0.765         0
# 3    0.357  2020        0.0194         0.935       187541   0.454         1
# 4    0.682  2020        0.4680         0.737       172325   0.802         1
#
#    instrumentalness  key  liveness  loudness  mode release_date  speechiness  \
# 0          0.000052    4    0.1130   -10.059     0   2020-10-30       0.0544
# 1          0.000000    7    0.2720    -3.558     0   2020-07-24       0.0369
# 2          0.000000    6    0.0936    -4.410     0   2020-08-28       0.0993
# 3          0.000000    1    0.0824    -7.509     1   2020-08-07       0.3750
# 4          0.000000    0    0.0931    -4.771     1   2020-10-30       0.0878
#
#      tempo  is_billboard  label
# ...
